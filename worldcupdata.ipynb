# %%
import pandas
from app import get_wc_data
wc_data = get_wc_data()

# %%
pandas.DataFrame(wc_data).query('competition=="women"')
# Out:
#           country  year competition
# 21  United States  1991       women
# 22         Norway  1995       women
# 23  United States  1999       women
# 24        Germany  2003       women
# 25        Germany  2007       women
# 26          Japan  2011       women
# 27  United States  2015       women
# 28  United States  2019       women

# %%
import numpy as np
df = pandas.DataFrame(wc_data)
pandas.Series(df['country']).value_counts()
df['country'].value_counts()
# Out:
# Brazil           5
# Italy            4
# United States    4
# Germany          3
# West Germany     3
# France           2
# Argentina        2
# Uruguay          2
# Spain            1
# England          1
# Norway           1
# Japan            1
# Name: country, dtype: int64

# %%
import matplotlib.pyplot as plt


s=df['country'].value_counts().to_dict()
plt.barh(list(s.keys()), list(s.values()))
# Out:
# <BarContainer object of 12 artists>
